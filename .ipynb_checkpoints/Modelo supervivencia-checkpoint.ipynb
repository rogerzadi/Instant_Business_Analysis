# %%
import json
import requests
import pandas as pd
import folium

# %%
giro="ropa"
long=19.421336 
lat=-99.162700
mts=1000

# %%
response = requests.get("https://www.inegi.org.mx/app/api/denue/v1/consulta/Buscar/{}/{},{}/{}/44522d01-cae7-455b-9b53-7fc7d481cecb".format(giro,long,lat,mts))
results = response.json()

data = pd.DataFrame(response.json())
data.head()
# Out:
#       CP            Calle          CentroComercial  \
# 0  06700      CHAPULTEPEC
# 1  06700           OAXACA
# 2  06700           JALAPA
# 3  06700  INSURGENTES SUR  NO ME LO PROPORCIONARON
# 4  06700           JALAPA
#
#                                      Clase_actividad     Colonia  \
# 0  Comercio al por menor de ropa, excepto de bebé...  ROMA NORTE
# 1       Confección de prendas de vestir sobre medida  ROMA NORTE
# 2          Comercio al por menor de artículos usados  ROMA NORTE
# 3    Fabricación de ropa exterior de tejido de punto  ROMA NORTE
# 4  Comercio al por menor de ropa, excepto de bebé...  ROMA NORTE
#
#                     Correo_e         Estrato       Id      Latitud  \
# 0                             0 a 5 personas  1028566  19.42291204
# 1                             0 a 5 personas  7732571  19.42267289
# 2                             0 a 5 personas  8386350  19.42303170
# 3  ISPANACAPITAL@HOTMAIL.COM  0 a 5 personas   657665  19.41977970
# 4        LEMURSHOP@GMAIL.COM  0 a 5 personas  1029621  19.41941920
#
#        Longitud  ... NumLocal Num_Exterior Num_Interior  \
# 0  -99.16300694  ...
# 1  -99.16370774  ...                    12
# 2  -99.16240274  ...                    13
# 3  -99.16400320  ...      216          216            0
# 4  -99.16151743  ...                    85            0
#
#                  Razon_social                Sitio_internet Telefono  Tipo  \
# 0                              WWW.ERICK-MARBOUTIQUE.COM.MX           Fijo
# 1  SHAILLA VALDERRAMA LOYOLA                                          Fijo
# 2        VENTA DE ROPA USADA                                          Fijo
# 3                                                                     Fijo
# 4                                                                     Fijo
#
#                  TipoCentroComercial Tipo_vialidad  \
# 0                                          AVENIDA
# 1                                          AVENIDA
# 2                                            CALLE
# 3  EDIFICIO COMERCIAL Y DE SERVICIOS       AVENIDA
# 4                                            CALLE
#
#                                   Ubicacion
# 0  CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO
# 1  CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO
# 2  CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO
# 3  CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO
# 4  CUAUHTÉMOC, Cuauhtémoc, CIUDAD DE MÉXICO
#
# [5 rows x 21 columns]

# %%
len(data)
# Out:
# 127

# %%
datafe = pd.read_csv('denue_inegi_09.csv',encoding = "ISO-8859-1")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Limpieza info
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466301 entries, 0 to 466300
# Data columns (total 12 columns):
# id            466301 non-null int32
# nom_estab     466301 non-null category
# codigo_act    466301 non-null int32
# nombre_act    466301 non-null category
# tipoCenCom    88178 non-null category
# tipoUniEco    466301 non-null category
# ageb          466285 non-null category
# manzana       466285 non-null float64
# latitud       466301 non-null float64
# longitud      466301 non-null float64
# fecha_alta    466301 non-null category
# www           37279 non-null category
# dtypes: category(7), float64(3), int32(2)
# memory usage: 33.9 MB

# %%
info=datafe[["id","nom_estab","codigo_act","nombre_act","tipoCenCom","tipoUniEco","ageb","manzana","latitud","longitud","fecha_alta","www"]]
for e in info.select_dtypes('object').columns:
    info[e]=info[e].astype('category')
for e in info.select_dtypes('integer').columns:
    info[e]=pd.to_numeric(info[e], downcast='integer')
for e in data.select_dtypes('float').columns:
    info[e]=pd.to_numeric(info[e], downcast='float')
info.info()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466301 entries, 0 to 466300
# Data columns (total 12 columns):
# id            466301 non-null int32
# nom_estab     466301 non-null category
# codigo_act    466301 non-null int32
# nombre_act    466301 non-null category
# tipoCenCom    88178 non-null category
# tipoUniEco    466301 non-null category
# ageb          466285 non-null category
# manzana       466285 non-null float64
# latitud       466301 non-null float64
# longitud      466301 non-null float64
# fecha_alta    466301 non-null category
# www           37279 non-null category
# dtypes: category(7), float64(3), int32(2)
# memory usage: 33.9 MB

# %%
empresas=data.Id
len(empresas)
# Out:
# 127

# %%
d=info[info["id"].isin(empresas)]
d.ageb
# Out:
# 3630      0998
# 4398      1106
# 4762      0998
# 5157      095A
# 5168      1093
# 5815      1002
# 6161      1110
# 6516      095A
# 11029     0856
# 14505     0841
# 14525     0841
# 14528     0841
# 20582     1093
# 36715     0945
# 38882     0841
# 47309     1089
# 51703     1017
# 75414     095A
# 75450     095A
# 75456     0803
# 76441     095A
# 79556     095A
# 80919     095A
# 81272     1093
# 82473     0803
# 82501     095A
# 82507     0803
# 83318     1017
# 83375     1017
# 86980     1214
#           ...
# 213041    095A
# 213676    1106
# 222755    1002
# 222770    0945
# 222809    095A
# 223058    0841
# 223317    095A
# 223318    0945
# 223348    0841
# 223395    0841
# 223560    0841
# 224183    1017
# 224211    0945
# 224262    0998
# 224376    1002
# 228675    095A
# 232094    0803
# 232095    0803
# 233045    0803
# 233133    1375
# 238929    1002
# 244124    1110
# 248450    1002
# 249032    1093
# 250359    095A
# 250690    095A
# 251387    1017
# 254064    095A
# 254073    0803
# 271097    095A
# Name: ageb, Length: 127, dtype: object

# %%
llat=list(d.latitud)
llong=list(d.longitud)
name=list(d.nom_estab)

mapa=folium.Map(location=[long, lat], tiles='openstreetmap', zoom_start=15)

for i in range(len(d)):
    folium.Marker([llat[i], llong[i]], icon=folium.Icon(color='red'),popup=name[i]).add_to(mapa)
    
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
d["fecha_alta"]=pd.to_datetime(d.fecha_alta) 
d.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            id                                nom_estab  \
# 3630  7732571  BOUTIQUE DE ROPA SOREIM FASHION ATELIER
# 4398   863029                           DOCE CERO TRES
# 4762  8326112   ELABORACIÓN DE VESTIMENTA HECHO MXCITY
# 5157  1028977                       FIDENZE COLLEZIONE
# 5168  8326350                 FLOR DE MAYO ESTRATEGIAS
#
#                                raz_social  codigo_act  \
# 3630           SHAILLA VALDERRAMA LOYOLA       315225
# 4398                                  NaN      315229
# 4762                HECHO MXCITY SA DE CV      315229
# 5157                                           315229
# 5168  FLOR DE MAYO ESTRATEGIAS SAPI DE CV      315229
#
#                                              nombre_act           per_ocu  \
# 3630       Confección de prendas de vestir sobre medida    0 a 5 personas
# 4398  Confección en serie de otra ropa exterior de m...    0 a 5 personas
# 4762  Confección en serie de otra ropa exterior de m...    0 a 5 personas
# 5157  Confección en serie de otra ropa exterior de m...    0 a 5 personas
# 5168  Confección en serie de otra ropa exterior de m...  31 a 50 personas
#
#      tipo_vial                nom_vial tipo_v_e_1        nom_v_e_1  ...  \
# 3630   AVENIDA                  OAXACA    AVENIDA  INSURGENTES SUR  ...
# 4398   AVENIDA          ALVARO OBREGON      CALLE           JALAPA  ...
# 4762     CALLE              VALLADOLID    AVENIDA      CHAPULTEPEC  ...
# 5157  EJE VIAL  2 PONIENTE (FLORENCIA)      CALLE          LONDRES  ...
# 5168     CALLE                 TABASCO    AVENIDA  INSURGENTES SUR  ...
#
#        localidad  ageb manzana telefono                 correoelec  \
# 3630  Cuauhtémoc  0998    19.0      NaN                        NaN
# 4398  Cuauhtémoc  1106    10.0      NaN   VINCENT@DOCECEROTRES.COM
# 4762  Cuauhtémoc  0998     9.0      NaN  JULIO@HECHOMEXICOCITY.COM
# 5157  Cuauhtémoc  095A     6.0      NaN                        NaN
# 5168  Cuauhtémoc  1093    11.0      NaN                        NaN
#
#                           www tipoUniEco    latitud   longitud fecha_alta
# 3630                      NaN       Fijo  19.422673 -99.163708 2019-11-01
# 4398  WWW.DOCECEROTRES.COM.MX       Fijo  19.417928 -99.160441 2010-07-01
# 4762         WWW.HECHO.COM.MX       Fijo  19.421939 -99.168670 2019-11-01
# 5157                      NaN       Fijo  19.423575 -99.165789 2010-07-01
# 5168                      NaN       Fijo  19.417781 -99.165862 2019-11-01
#
# [5 rows x 41 columns]

# %%
import statsmodels.api as sm
day=d["fecha_alta"]
day.plot();

# %%
#Indice nacional de precios al consumidor

# %%
da= pd.read_csv("../AGEEML.csv",encoding = "utf-8")

# %%
da
# Out:
#     Cve_Ent           Nom_Ent Nom_Abr  Cve_Mun                 Nom_Mun  \
# 0         9  Ciudad de México    CDMX        2            Azcapotzalco
# 1         9  Ciudad de México    CDMX        3                Coyoacán
# 2         9  Ciudad de México    CDMX        4   Cuajimalpa de Morelos
# 3         9  Ciudad de México    CDMX        5       Gustavo A. Madero
# 4         9  Ciudad de México    CDMX        6               Iztacalco
# 5         9  Ciudad de México    CDMX        7              Iztapalapa
# 6         9  Ciudad de México    CDMX        8  La Magdalena Contreras
# 7         9  Ciudad de México    CDMX        9              Milpa Alta
# 8         9  Ciudad de México    CDMX       10          Álvaro Obregón
# 9         9  Ciudad de México    CDMX       11                 Tláhuac
# 10        9  Ciudad de México    CDMX       12                 Tlalpan
# 11        9  Ciudad de México    CDMX       13              Xochimilco
# 12        9  Ciudad de México    CDMX       14           Benito Juárez
# 13        9  Ciudad de México    CDMX       15              Cuauhtémoc
# 14        9  Ciudad de México    CDMX       16          Miguel Hidalgo
# 15        9  Ciudad de México    CDMX       17     Venustiano Carranza
#
#     Cve_Cab  Nom_Cab  Pob_Total  Total De Viviendas Habitadas  Pob_Masculina  \
# 0       NaN      NaN     414711                        117264         196053
# 1       NaN      NaN     620416                        180946         292491
# 2       NaN      NaN     186391                         47897          88642
# 3       NaN      NaN    1185772                        320756         571233
# 4       NaN      NaN     384326                        104406         182534
# 5       NaN      NaN    1815786                        460747         880998
# 6       NaN      NaN     239086                         63267         114492
# 7       NaN      NaN     130582                         31820          64192
# 8       NaN      NaN     727034                        197926         346041
# 9       NaN      NaN     360265                         91254         175210
# 10      NaN      NaN     650567                        176086         312139
# 11      NaN      NaN     415007                        102778         205305
# 12      NaN      NaN     385439                        141203         176410
# 13      NaN      NaN     531831                        173907         251725
# 14      NaN      NaN     372889                        120186         172667
# 15      NaN      NaN     430978                        123327         203651
#
#     Pob_Femenina
# 0         218658
# 1         327925
# 2          97749
# 3         614539
# 4         201792
# 5         934788
# 6         124594
# 7          66390
# 8         380993
# 9         185055
# 10        338428
# 11        209702
# 12        209029
# 13        280106
# 14        200222
# 15        227327
